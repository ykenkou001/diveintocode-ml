# %% [markdown]
# # 1.このSprintについて
# Sprintの目的
# スクラッチを通して線形回帰を理解する
# オブジェクト指向を意識した実装に慣れる
# 数式をコードに落とし込めるようにする
# どのように学ぶか
# スクラッチで線形回帰を実装した後、学習と検証を行なっていきます。

# %% [markdown]
# # 2.線形回帰スクラッチ
# 線形回帰のクラスをスクラッチで作成していきます。NumPyなど最低限のライブラリのみを使いアルゴリズムを実装していきます。
#
# 以下に雛形を用意してあります。このScratchLinearRegressionクラスにコードを書き加えていってください。

# %% [markdown]
# ## データを読み込む

# %%
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
def scratch_train_test_split(X, y, train_size=0.8,):
    """
    検証用データを分割する。

    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      学習データ
    y : 次の形のndarray, shape (n_samples, )
      正解値
    train_size : float (0<train_size<1)
      何割をtrainとするか指定

    Returns
    ----------
    X_train : 次の形のndarray, shape (n_samples, n_features)
      学習データ
    X_test : 次の形のndarray, shape (n_samples, n_features)
      検証データ
    y_train : 次の形のndarray, shape (n_samples, )
      学習データの正解値
    y_test : 次の形のndarray, shape (n_samples, )
      検証データの正解値
    """
    import numpy as np
    
    per = len(y) #サンプル数(インデックス数)を取得
    split_size = int(per*train_size) #train_sizeでサンプル数を分ける
    shuffle_index = np.random.permutation(per) #sampleのインデックスをshuffleして変数に格納
    #インデックスをshuffle_index、split_sizeでスライスしていく
    X_train = X[shuffle_index][:split_size]
    X_test = X[shuffle_index][split_size:]
    y_train = y[shuffle_index][:split_size]
    y_test = y[shuffle_index][split_size:]
    
    return X_train, X_test, y_train, y_test

# %%
import pandas as pd

pd.set_option('display.max_columns', 200)# 表示する列名を省略しない

df = pd.read_csv('train.csv')
df.head()

X = df[['GrLivArea', 'YearBuilt']] # 2つの特徴量を抜き出し変数に格納
y = df[['SalePrice']] # 目的変数を抜き出し、変数に格納

X = X.astype('float64')
y = y.astype('float64')

# %%
#train_test_split
X_train, X_test, y_train, y_test = scratch_train_test_split(X.values, y.values, 0.8)

#標準化処理を行う
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

#　標準化する
scaler = StandardScaler()
scaler.fit(X_train)
# 標準化変形する

X_train_transformed = scaler.transform(X_train)
X_test_transformed = scaler.transform(X_test)

# %% [markdown]
# ## 雛型

# %%
class ScratchLinearRegression():
    """
    線形回帰のスクラッチ実装

    Parameters
    ----------
    num_iter : int
      イテレーション数
    lr : float
      学習率
    no_bias : bool
      バイアス項を入れない場合はTrue
    verbose : bool
      学習過程を出力する場合はTrue

    Attributes
    ----------
    self.coef_ : 次の形のndarray, shape (n_features,)
      パラメータ
    self.loss : 次の形のndarray, shape (self.iter,)
      学習用データに対する損失の記録
    self.val_loss : 次の形のndarray, shape (self.iter,)
      検証用データに対する損失の記録

    """

    def __init__(self, num_iter, lr, bias, verbose):
        # ハイパーパラメータを属性として記録
        self.iter = num_iter
        self.lr = lr
        self.bias = bias
        self.verbose = verbose
        # 損失を記録する配列を用意
        self.loss = np.zeros(self.iter)
        self.val_loss = np.zeros(self.iter)
        
       
        

    def fit(self, X, y, X_val=None, y_val=None):
        """
        線形回帰を学習する。検証用データが入力された場合はそれに対する損失と精度もイテレーションごとに計算する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            学習用データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            学習用データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証用データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証用データの正解値
        """

        if self.verbose:
            j_theta = 1/ (2*Xshape[0]) * ((_linear_hypothesis(self, X) - y)**2)
            #verboseをTrueにした際は学習過程を出力
            print()
        pass


    def predict(self, X):
        """
        線形回帰を使い推定する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            サンプル

        Returns
        -------
            次の形のndarray, shape (n_samples, 1)
            線形回帰による推定結果
        """
        y_pred = np.dot(X, self.coef_) # thetaは最急降下法で求めたもの,
        
        return y_pred

# %% [markdown]
# # 【問題1】仮定関数
# 以下の数式で表される線形回帰の仮定関数を実装してください。メソッドの雛形を用意してあります。
#
# $$
# h_
# θ
# (
# x
# )
# =
# θ_
# 0
# x_
# 0
# +
# θ_
# 1
# x_
# 1
# +
# .
# .
# .
# +
# θ_
# j
# x_
# j
# +
# .
# .
# .
# +
# θ_
# n
# x_
# n
# .
# (
# x_
# 0
# =
# 1
# )
# $$
#
# x : 特徴量ベクトル
# θ: パラメータベクトル
# n: 特徴量の数
# $x_j$: j番目の特徴量
# $θ_j$: j番目のパラメータ（重み）
# 特徴量の数$
# n$は任意の値に対応できる実装にしてください。
# なお、ベクトル形式で表すと以下のようになります。
#
# $$
# h_
# θ
# (
# x
# )
# =
# θ^
# T
# ⋅
# x
# .
# $$

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## 確認用に適当な値をX,theta,alpha,yを決める

# %%
#4*2の特徴量にx0の1を追加すると４＊３
X_0 = np.random.rand(4, 2)
print("X_0 : \n{}".format(X_0))
# 重みtheta
theta_0 = np.random.rand(3)
print("theta_0 : \n{}".format(theta_0))
# 学習率alpha
alpha = 0.01
# 目的変数ｙ
y = np.random.rand(4)
print("目的変数ｙ : {}".format(y))
print("X_1:shape : {}".format(X_0.shape))
print("theta_0:shape : {}".format(theta_0.shape))
# Out:
# X_0 :
# [[0.03939497 0.95771771]
#  [0.29260199 0.11879305]
#  [0.78401441 0.49324038]
#  [0.48660983 0.43428712]]
# theta_0 :
# [0.67797026 0.75853427 0.5175726 ]
# 目的変数ｙ : [0.13560324 0.39175443 0.66814032 0.74632264]
# X_1:shape : (4, 2)
# theta_0:shape : (3,)

# %% [markdown]
# ## 仮定関数

# %%
def _linear_hypothesis(X, theta):
    """
    線形の仮定関数を計算する

    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      学習データ

    Returns
    -------
      次の形のndarray, shape (n_samples, 1)
      線形の仮定関数による推定結果

    """
    
    X = np.insert(X, 0, np.ones(X.shape[0]), axis=1) # Xの0列目に１を代入
    #theta = np.random.rand(X.shape[1], 1) # thetaを定義
    f_x = np.dot(X, theta.T) # Xとthetaの内積
    
    return f_x

# %% [markdown]
# ### 確認

# %%
#確認

print(_linear_hypothesis(X_0, theta_0))
# Out:
# [1.20354115 0.96140293 1.52795976 1.27185561]

# %% [markdown]
# ## クラス用

# %%
# クラス用

def _linear_hypothesis(self, X):
    """
    線形の仮定関数を計算する

    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      学習データ

    Returns
    -------
      次の形のndarray, shape (n_samples, 1)
      線形の仮定関数による推定結果

    """
    
    X = np.insert(X, 0, np.ones(X.shape[0]), axis=1) # Xの0列目に１を代入
    f_x = np.dot(X, self.coef_.T) # Xとthetaの内積
    
    return f_x

# %% [markdown]
# # 【問題2】最急降下法
# 最急降下法により学習させる実装を行なってください。以下の式で表されるパラメータの更新式のメソッド_gradient_descentを追加し、fit
# メソッドから呼び出すようにしてください。
#
# $$
# θ_j:=θ_j−α\frac{1}{m}\sum_{i=0}^{m} \quad[(h_θ(x^{(i)})−y^{(i)})x^{(i)}_j]
# $$
#
# α: 学習率
# i : サンプルのインデックス
# j : 特徴量のインデックス
#
# 雛形として用意されたメソッドや関数以外でも必要があれば各自作成して完成させてください。雛形を外れても問題ありません。

# %% [markdown]
# [初歩からの機械学習：最急降下法による重回帰モデル～PythonとRでスクラッチから～](https://www.medi-08-data-06.work/entry/grad_desc_reg#%E6%9C%80%E6%80%A5%E9%99%8D%E4%B8%8B%E6%B3%95%E3%81%AB%E3%82%88%E3%82%8B%E9%87%8D%E5%9B%9E%E5%B8%B0%E3%83%A2%E3%83%87%E3%83%AB)

# %%
print(theta_0)
print(X_0)
# Out:
# [0.67797026 0.75853427 0.5175726 ]
# [[0.03939497 0.95771771]
#  [0.29260199 0.11879305]
#  [0.78401441 0.49324038]
#  [0.48660983 0.43428712]]

# %%
#　最適なパラメータthetaを求める

def _gradient_descent(theta, alpha, X, y):
    """
    y : 目的変数（ベクトル）
    theta : thetaの初期値（重みベクトル）
    itera : 繰り返し回数
    X : 特徴量（行列）
    alpha : 学習率
    
    """
    
    X = np.insert(X, 0, np.ones(X.shape[0]), axis=1) # Xの0列目に１を代入
    f_x = np.dot(X, theta.T) # Xとthetaの内積
    error = f_x - y #差分（ベクトル）
    theta = theta - alpha / X.shape[0] * (np.dot(error.T, X)) #最急降下法
    
    return theta

# %% [markdown]
# ### 確認

# %%
_gradient_descent(theta_0, alpha, X_0, y)
# 最適なパラメータが求まる
# Out:
# array([0.67041292, 0.75568779, 0.51321565])

# %% [markdown]
# ## errorを求める

# %%
# error = f_x - y

# %% [markdown]
# ## クラス用

# %%
def _gradient_descent(self, X, error):
    """
    X : 次の形のndarray, shape (n_samples, n_features)
            学習用データの特徴量
    error : 次の形のndarray, shape (n_samples, )
    """
    self.coef_ = self.coef_ - self.lr / X.shape[0] * (np.dot(error.T, X)) #最急降下法
    
    return self.coef_

# %% [markdown]
# # 【問題3】推定
# 推定する仕組みを実装してください。ScratchLinearRegressionクラスの雛形に含まれるpredictメソッドに書き加えてください。
#
# 仮定関数   $
# h
# θ
# (
# x
# )
# $ の出力が推定結果です。

# %%
class ScratchLinearRegression():
    """
    線形回帰のスクラッチ実装

    Parameters
    ----------
    num_iter : int
      イテレーション数
    lr : float
      学習率
    no_bias : bool
      バイアス項を入れない場合はTrue
    verbose : bool
      学習過程を出力する場合はTrue

    Attributes
    ----------
    self.coef_ : 次の形のndarray, shape (n_features,)
      パラメータ
    self.loss : 次の形のndarray, shape (self.iter,)
      学習用データに対する損失の記録
    self.val_loss : 次の形のndarray, shape (self.iter,)
      検証用データに対する損失の記録

    """

    def __init__(self, num_iter, lr, bias, verbose):
        # ハイパーパラメータを属性として記録
        self.iter = num_iter
        self.lr = lr
        self.bias = bias
        self.verbose = verbose
        # 損失を記録する配列を用意
        self.loss = np.zeros(self.iter)
        self.val_loss = np.zeros(self.iter)

    def fit(self, X, y, X_val=None, y_val=None):
        """
        線形回帰を学習する。検証用データが入力された場合はそれに対する損失と精度もイテレーションごとに計算する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            学習用データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            学習用データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証用データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証用データの正解値
        """

        if self.verbose:
            #verboseをTrueにした際は学習過程を出力
            print()
        pass


    def predict(self, X):
        """
        線形回帰を使い推定する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            サンプル

        Returns
        -------
            次の形のndarray, shape (n_samples, 1)
            線形回帰による推定結果
        """

        pass
        return

# %%
def predict(X, theta):
        """
        線形回帰を使い推定する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            サンプル

        Returns
        -------
            次の形のndarray, shape (n_samples, 1)
            線形回帰による推定結果
        """
        y_pred = np.dot(X, theta) # thetaは最急降下法で求めたもの,
        
        
        return y_pred

# %%
# 確認  np.insert(X, 0, np.ones(X.shape[0]), axis=1)
predict_y =  predict(np.insert(X_0, 0, 1, axis=1), theta_0)
print(predict_y)
# Out:
# [1.20354115 0.96140293 1.52795976 1.27185561]

# %% [markdown]
# # 【問題4】平均二乗誤差
# 線形回帰の指標値として用いられる平均二乗誤差（mean square error, MSE）の関数を作成してください。
#
# 平均二乗誤差関数は回帰問題全般で使える関数のため、ScratchLinearRegressionクラスのメソッドではなく、別の関数として作成してください。雛形を用意してあります。
#
# 平均二乗誤差は以下の数式で表されます。
#
# $$
# L(θ)=1mm∑i=1 (h_θ(x^{(i)})−y^{(i)})^2.
# $$
#
# m : 入力されるデータの数
# $h_θ()$ : 仮定関数
# $x^{(i)}$ : i番目のサンプルの特徴量ベクトル
# $y^{(i)}$ : i番目のサンプルの正解値
#
# なお、最急降下法のための目的関数（損失関数）としては、これを2で割ったものを使用します。（問題5, 9）

# %%
def MSE(y_pred, y):
    """
    平均二乗誤差の計算

    Parameters
    ----------
    y_pred : 次の形のndarray, shape (n_samples,)
      推定した値
    y : 次の形のndarray, shape (n_samples,)
      正解値

    Returns
    ----------
    mse : numpy.float
      平均二乗誤差
    """
    m = y_pred.shape[0] # 入力されるデータ数＝y_predの行数
    
    mse = (1/m)* np.sum((y_pred - y)**2)
    
    return mse

# %%
MSE(predict_y, y)
# Out:
# 0.6201162922883418

# %% [markdown]
# # 【問題5】目的関数
# 以下の数式で表される線形回帰の 目的関数（損失関数） を実装してください。そして、これをself.loss, self.val_lossに記録するようにしてください。

# %% [markdown]
# # クラス作成

# %%
class ScratchLinearRegression():
    """
    線形回帰のスクラッチ実装

    Parameters
    ----------
    num_iter : int
      イテレーション数
    lr : float
      学習率
    no_bias : bool
      バイアス項を入れない場合はTrue
    verbose : bool
      学習過程を出力する場合はTrue

    Attributes
    ----------
    self.coef_ : 次の形のndarray, shape (n_features,)
      パラメータ
    self.loss : 次の形のndarray, shape (self.iter,)
      学習用データに対する損失の記録
    self.val_loss : 次の形のndarray, shape (self.iter,)
      検証用データに対する損失の記録

    """

    def __init__(self, num_iter=300, lr=0.02, bias=True, verbose=False):
        # ハイパーパラメータを属性として記録
        self.iter = num_iter # 学習回数
        self.lr = lr # 学習率
        self.bias = bias # バイアス項（切片）
        self.verbose = verbose # 学習過程を出力するか否か
        
        # 損失を記録する配列を用意
        self.loss = np.zeros(self.iter)
        self.val_loss = np.zeros(self.iter)
        
        #パラメータを用意
        np.random.seed(5)
        self.coef_ = 0
        

    def fit(self, X, y, X_val=None, y_val=None):
        """
        線形回帰を学習する。検証用データが入力された場合はそれに対する損失と精度もイテレーションごとに計算する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            学習用データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            学習用データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証用データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証用データの正解値
        """
         # バイアス項を入れる
        hoge = np.ones((X.shape[0],1))
        if self.bias == False:
            # Xの0列目に１を代入
            X = np.concatenate([hoge,X],axis=1)
            
            #検証用データ有り
            if X_val is not None and y_val is not None:
                hoge_0 = np.ones((X_val.shape[0],1))
                # X_valの0列目に１を代入
                X_val = np.concatenate([hoge_0, X_val],axis=1)
        
        #パラメータの初期値
        np.random.seed(51)
        self.coef_ = np.random.rand(X.shape[1])#[np.newaxis, :]
        self.coef_ = self.coef_[np.newaxis, :]
        
        #カウント
        count = 0
        
        #学習
        #verboseをTrueにした際は学習過程を出力
        for i in range(self.iter):
            
            #仮定関数
            f_x = self._linear_hypothesis(X)
            # errorを定義
            error = f_x - y
            #パラメータを更新していく    _gradient_descent(self, X, error)
            self.coef_ = self._gradient_descent(X, error)
            #学習データの損失を記録する
            m = MSE(f_x, y) / 2
            self.loss[i] = m
            
            # 検証用データ有り,損失を記録
            if X_val is not None and y_val is not None:
                f_x_1 = self._linear_hypothesis(X_val)
                self.val_loss[i] = MSE(f_x_1, y_val) / 2
                
            #verboseをTrueにした際は学習過程を出力
            if self.verbose== True:
                count += 1
                print("{}回目の学習用データは : {}".format(count, self.loss[i]))
                # 検証用データ有り
                if X_val is not None and y_val is not None:
                    print("{}回目の検証用データは : {}".format(count, self.val_loss[i]))
                

    def predict(self, X):
        """
        線形回帰を使い推定する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            サンプル

        Returns
        -------
            次の形のndarray, shape (n_samples, 1)
            線形回帰による推定結果
        """
        
        
        self.y_pred = np.dot(X, self.coef_.T) # thetaは最急降下法で求めたもの,
        
        return self.y_pred
    
    

    def _linear_hypothesis(self, X):
        """
        線形の仮定関数を計算する

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
          学習データ

        Returns
        -------
          次の形のndarray, shape (n_samples, 1)
          線形の仮定関数による推定結果

        """

        #X = np.insert(X, 0, np.ones(X.shape[0]), axis=1) # Xの0列目に１を代入
        self.f_x = np.dot(X, self.coef_.T) # Xとthetaの内積

        return self.f_x
    
    def _gradient_descent(self, X, error):
        """
        X : 次の形のndarray, shape (n_samples, n_features)
                学習用データの特徴量
         error : 次の形のndarray, shape (n_samples, )

        """

        self.coef_ = self.coef_ - self.lr / X.shape[0] * (np.dot(error.T, X)) #最急降下法

        return self.coef_

    def MSE(y_pred, y):
        """
        平均二乗誤差の計算

        Parameters
        ----------
        y_pred : 次の形のndarray, shape (n_samples,)
          推定した値
        y : 次の形のndarray, shape (n_samples,)
          正解値

        Returns
        ----------
        mse : numpy.float
          平均二乗誤差
        """
        m = self.y_pred.shape[0] # 入力されるデータ数＝y_predの行数

        mse = ((1/m)* np.sum((y_pred - y)**2))

        return mse

# %% [markdown]
# # 3.検証

# %% [markdown]
# # 【問題6】学習と推定
# 機械学習スクラッチ入門のSprintで用意したHouse Pricesコンペティションのデータに対してスクラッチ実装の学習と推定を行なってください。
#
# scikit-learnによる実装と比べ、正しく動いているかを確認してください。

# %% [markdown]
# ## 学習、推定

# %%
#biasなし、出力なし
slr = ScratchLinearRegression(num_iter=300, lr=0.02, bias=True, verbose=False)
slr.fit(X_train_transformed, y_train, X_test_transformed, y_test)

# 推定
predict_slr = slr.predict(X_test_transformed)
# print(predict_slr)
print("自作MSE：{}".format(MSE(predict_slr, y_test)))
print("SklearnMSE : {}".format(mean_squared_error(y_test, predict_slr)))
# Out:
# 自作MSE：34476764852.08878
# SklearnMSE : 34476764852.08878

# %% [markdown]
# ## 学習曲線

# %%
#biasあり、出力あり
slr_0 = ScratchLinearRegression(num_iter=300, lr=0.02, bias=False, verbose=True)
slr_0.fit(X_train_transformed, y_train, X_test_transformed, y_test)
# Out:
# 1回目の学習用データは : 19944359738.279503
# 1回目の検証用データは : 17134526128.03162
# 2回目の学習用データは : 19183338684.492424
# 2回目の検証用データは : 16476735178.721706
# 3回目の学習用データは : 18453264192.575012
# 3回目の検証用データは : 15845543469.781239
# 4回目の学習用データは : 17752871634.88693
# 4回目の検証用データは : 15239872758.028713
# 5回目の学習用データは : 17080948349.630531
# 5回目の検証用データは : 14658688684.754898
# 6回目の学習用データは : 16436331492.224335
# 6回目の検証用データは : 14100998980.229803
# 7回目の学習用データは : 15817905976.125568
# 7回目の検証用データは : 13565851742.134813
# 8回目の学習用データは : 15224602499.350166
# 8回目の検証用データは : 13052333784.854202
# 9回目の学習用データは : 14655395653.09694
# 9回目の検証用データは : 12559569056.688274
# 10回目の学習用データは : 14109302109.034687
# 10回目の検証用データは : 12086717122.173292
# 11回目の学習用データは : 13585378881.956367
# 11回目の検証用データは : 11632971706.81088
# 12回目の学習用データは : 13082721664.643593
# 12回目の検証用データは : 11197559301.622274
# 13回目の学習用データは : 12600463231.918068
# 13回目の検証用データは : 10779737825.050636
# 14回目の学習用データは : 12137771910.984163
# 14回目の検証用データは : 10378795339.838097
# 15回目の学習用データは : 11693850115.28891
# 15回目の検証用データは : 9994048822.60309
# 16回目の学習用データは : 11267932939.242779
# 16回目の検証用データは : 9624842983.938423
# 17回目の学習用データは : 10859286811.256552
# 17回目の検証用データは : 9270549136.941473
# 18回目の学習用データは : 10467208202.656776
# 18回目の検証用データは : 8930564112.174686
# 19回目の学習用データは : 10091022390.145111
# 19回目の検証用データは : 8604309217.138243
# 20回目の学習用データは : 9730082269.564995
# 20回目の検証用データは : 8291229238.416316
# 21回目の学習用データは : 9383767218.833391
# 21回目の検証用データは : 7990791484.735104
# 22回目の学習用データは : 9051482007.985388
# 22回目の検証用データは : 7702484869.243999
# 23回目の学習用データは : 8732655754.365826
# 23回目の検証用データは : 7425819029.401474
# 24回目の学習用データは : 8426740921.084706
# 24回目の検証用データは : 7160323482.914647
# 25回目の学習用データは : 8133212356.932389
# 25回目の検証用データは : 6905546818.245816
# 26回目の学習用データは : 7851566376.026319
# 26回目の検証用データは : 6661055918.261143
# 27回目の学習用データは : 7581319875.533581
# 27回目の検証用データは : 6426435215.655762
# 28回目の学習用データは : 7322009489.883246
# 28回目の検証用データは : 6201285978.846271
# 29回目の学習用データは : 7073190779.948835
# 29回目の検証用データは : 5985225627.075959
# 30回目の学習用データは : 6834437455.745172
# 30回目の検証用データは : 5777887073.530121
# 31回目の学習用データは : 6605340631.244847
# 31回目の検証用データは : 5578918095.308661
# 32回目の学習用データは : 6385508109.978012
# 32回目の検証用データは : 5387980729.151046
# 33回目の学習用データは : 6174563700.135272
# 33回目の検証用データは : 5204750691.854397
# 34回目の学習用データは : 5972146557.947024
# 34回目の検証用データは : 5028916824.3694
# 35回目の学習用データは : 5777910558.164014
# 35回目の検証用データは : 4860180558.600794
# 36回目の学習用データは : 5591523690.513044
# 36回目の検証用データは : 4698255405.97942
# 37回目の学習用データは : 5412667481.048966
# 37回目の検証用データは : 4542866466.911504
# 38回目の学習用データは : 5241036437.369125
# 38回目の検証用データは : 4393749960.247769
# 39回目の学習用データは : 5076337516.699776
# 39回目の検証用データは : 4250652771.9504766
# 40回目の学習用データは : 4918289615.905314
# 40回目の検証用データは : 4113332022.1704516
# 41回目の学習用データは : 4766623082.510902
# 41回目の検証用データは : 3981554649.978738
# 42回目の学習用データは : 4621079245.867017
# 42回目の検証用データは : 3855097015.0286713
# 43回目の学習用データは : 4481409967.620871
# 43回目の検証用データは : 3733744515.4541526
# 44回目の学習用データは : 4347377210.694541
# 44回目の検証用データは : 3617291221.3384957
# 45回目の学習用データは : 4218752626.002989
# 45回目の検証用データは : 3505539523.1157293
# 46回目の学習用データは : 4095317156.177201
# 46回目の検証用データは : 3398299794.2925315
# 47回目の学習用データは : 3976860655.5883083
# 47回目の検証用データは : 3295390067.904266
# 48回目の学習用データは : 3863181525.9978876
# 48回目の検証用データは : 3196635726.142687
# 49回目の学習用データは : 3754086367.1878104
# 49回目の検証用データは : 3101869202.6161437
# 50回目の学習用データは : 3649389641.9499106
# 50回目の検証用データは : 3010929696.7252846
# 51回目の学習用データは : 3548913354.8416104
# 51回目の検証用データは : 2923662899.6585526
# 52回目の学習用データは : 3452486744.138306
# 52回目の検証用データは : 2839920731.5322213
# 53回目の学習用データは : 3359945986.43707
# 53回目の検証用データは : 2759561089.2192216
# 54回目の学習用データは : 3271133913.388894
# 54回目の検証用データは : 2682447604.429822
# 55回目の学習用データは : 3185899740.0584598
# 55回目の検証用データは : 2608449411.6251593
# 56回目の学習用データは : 3104098804.4312377
# 56回目の検証用データは : 2537440925.3618674
# 57回目の学習用データは : 3025592317.607724
# 57回目の検証用データは : 2469301626.682566
# 58回目の学習用データは : 2950247124.2436876
# 58回目の検証用データは : 2403915858.1828046
# 59回目の学習用データは : 2877935472.813694
# 59回目の検証用データは : 2341172627.4002376
# 60回目の学習用データは : 2808534795.2926884
# 60回目の検証用データは : 2280965418.1863413
# 61回目の学習用データは : 2741927495.867252
# 61回目の検証用データは : 2223192009.7349634
# 62回目の学習用データは : 2678000748.304282
# 62回目の検証用データは : 2167754302.9553266
# 63回目の学習用データは : 2616646301.6202874
# 63回目の検証用データは : 2114558153.8899636
# 64回目の学習用データは : 2557760293.7092743
# 64回目の検証用データは : 2063513213.8903294
# 65回目の学習用データは : 2501243072.6014137
# 65回目の検証用データは : 2014532776.274619
# 66回目の学習用データは : 2446999025.0382485
# 66回目の検証用データは : 1967533629.2036207
# 67回目の学習用データは : 2394936412.063219
# 67回目の検証用データは : 1922435914.5212586
# 68回目の学習用データは : 2344967211.338796
# 68回目の検証用データは : 1879162992.3168623
# 69回目の学習用データは : 2297006965.9134245
# 69回目の検証用データは : 1837641310.9761565
# 70回目の学習用データは : 2250974639.172982
# 70回目の検証用データは : 1797800282.4975
# 71回目の学習用データは : 2206792475.7224236
# 71回目の検証用データは : 1759572162.8590577
# 72回目の学習用データは : 2164385867.9537845
# 72回目の検証用データは : 1722891937.2313638
# 73回目の学習用データは : 2123683228.0668526
# 73回目の検証用データは : 1687697209.8381412
# 74回目の学習用データは : 2084615865.3184388
# 74回目の検証用データは : 1653928098.2763057
# 75回目の学習用データは : 2047117868.2854512
# 75回目の検証用データは : 1621527132.113827
# 76回目の学習用データは : 2011125991.9358828
# 76回目の検証用データは : 1590439155.5915105
# 77回目の学習用データは : 1976579549.3102858
# 77回目の検証用データは : 1560611234.261901
# 78回目の学習用データは : 1943420307.6244912
# 78回目の検証用データは : 1531992565.4053051
# 79回目の学習用データは : 1911592388.6121528
# 79回目の検証用データは : 1504534392.0694716
# 80回目の学習用データは : 1881042172.9331474
# 80回目の検証用データは : 1478189920.5857444
# 81回目の学習用データは : 1851718208.4810932
# 81回目の検証用データは : 1452914241.4204984
# 82回目の学習用データは : 1823571122.430081
# 82回目の検証用データは : 1428664253.2264435
# 83回目の学習用データは : 1796553536.8673415
# 83回目の検証用データは : 1405398589.963909
# 84回目の学習用データは : 1770619987.8648834
# 84回目の検証用データは : 1383077550.9675062
# 85回目の学習用データは : 1745726847.8491833
# 85回目の検証用データは : 1361663033.8386652
# 86回目の学習用データは : 1721832251.1338325
# 86回目の検証用データは : 1341118470.0494125
# 87回目の学習用データは : 1698896022.4856124
# 87回目の検証用データは : 1321408763.1474154
# 88回目の学習用データは : 1676879608.5997858
# 88回目の検証用データは : 1302500229.4568214
# 89回目の学習用データは : 1655746012.3655298
# 89回目の検証用データは : 1284360541.1737075
# 90回目の学習用データは : 1635459729.8073242
# 90回目の検証用データは : 1266958671.7590733
# 91回目の学習用データは : 1615986689.5928185
# 91回目の検証用データは : 1250264843.536275
# 92回目の学習用データは : 1597294195.0021856
# 92回目の検証用データは : 1234250477.403585
# 93回目の学習用データは : 1579350868.2583215
# 93回目の検証用データは : 1218888144.576186
# 94回目の学習用データは : 1562126597.1213536
# 94回目の検証用データは : 1204151520.2754202
# 95回目の学習用データは : 1545592483.6549172
# 95回目の検証用データは : 1190015339.2864332
# 96回目の学習用データは : 1529720795.0754478
# 96回目の検証用データは : 1176455353.3085752
# 97回目の学習用データは : 1514484916.5993843
# 97回目の検証用データは : 1163448290.0259893
# 98回目の学習用データは : 1499859306.2066839
# 98回目の検証用データは : 1150971813.82878
# 99回目の学習用データは : 1485819451.2423902
# 99回目の検証用データは : 1139004488.1179712
# 100回目の学習用データは : 1472341826.781216
# 100回目の検証用データは : 1127525739.1301792
# 101回目の学習用データは : 1459403855.6831777
# 101回目の検証用データは : 1116515821.2205408
# 102回目の学習用データは : 1446983870.2712765
# 102回目の検証用データは : 1105955783.5449216
# 103回目の学習用データは : 1435061075.565043
# 103回目の検証用データは : 1095827438.0848255
# 104回目の学習用データは : 1423615514.0064914
# 104回目の検証用データは : 1086113328.960736
# 105回目の学習用データは : 1412628031.6176167
# 105回目の検証用データは : 1076796702.9818022
# 106回目の学習用データは : 1402080245.531073
# 106回目の検証用データは : 1067861481.3819215
# 107回目の学習用データは : 1391954512.838056
# 107回目の検証用データは : 1059292232.6942686
# 108回目の学習用データは : 1382233900.699712
# 108回目の検証用データは : 1051074146.718299
# 109回目の学習用データは : 1372902157.6705973
# 109回目の検証用データは : 1043193009.5350868
# 110回目の学習用データは : 1363943686.1848028
# 110回目の検証用データは : 1035635179.5286733
# 111回目の学習用データは : 1355343516.1574066
# 111回目の検証用データは : 1028387564.3728001
# 112回目の学習用データは : 1347087279.6558332
# 112回目の検証用データは : 1021437598.94406
# 113回目の学習用データは : 1339161186.5975654
# 113回目の検証用データは : 1014773224.1240685
# 114回目の学習用データは : 1331552001.4324424
# 114回目の検証用データは : 1008382866.4547833
# 115回目の学習用データは : 1324247020.7694705
# 115回目の検証用データは : 1002255418.6125404
# 116回目の学習用データは : 1317234051.9097302
# 116回目の検証用データは : 996380220.667783
# 117回目の学習用データは : 1310501392.2485204
# 117回目の検証用データは : 990747042.0987896
# 118回目の学習用データは : 1304037809.5113904
# 118回目の検証用データは : 985346064.528986
# 119回目の学習用データは : 1297832522.7901597
# 119回目の検証用データは : 980167865.1586734
# 120回目の学習用データは : 1291875184.346405
# 120回目の検証用データは : 975203400.863162
# 121回目の学習用データは : 1286155862.151225
# 121回目の検証用データは : 970443992.9304546
# 122回目の学習用データは : 1280665023.1313632
# 122回目の検証用データは : 965881312.4126987
# 123回目の学習用データは : 1275393517.0929973
# 123回目の検証用データは : 961507366.0666727
# 124回目の学習用データは : 1270332561.2956731
# 124回目の検証用データは : 957314482.8595654
# 125回目の学習用データは : 1265473725.649972
# 125回目の検証用データは : 953295301.0172825
# 126回目の学習用データは : 1260808918.5136008
# 126回目の検証用データは : 949442755.593418
# 127回目の学習用データは : 1256330373.0616052
# 127回目の検証用データは : 945750066.5379199
# 128回目の学習用データは : 1252030634.2074091
# 128回目の検証用データは : 942210727.2453272
# 129回目の学習用データは : 1247902546.0523283
# 129回目の検証用データは : 938818493.5632694
# 130回目の学習用データは : 1243939239.842124
# 130回目の検証用データは : 935567373.2426898
# 131回目の学習用データは : 1240134122.410022
# 131回目の検証用データは : 932451615.8120173
# 132回目の学習用データは : 1236480865.0864792
# 132回目の検証用データは : 929465702.8582191
# 133回目の学習用データは : 1232973393.0567667
# 133回目の検証用データは : 926604338.698358
# 134回目の学習用データは : 1229605875.1482205
# 134回目の検証用データは : 923862441.42594
# 135回目の学習用データは : 1226372714.0297422
# 135回目の検証用データは : 921235134.3169719
# 136回目の学習用データは : 1223268536.8068483
# 136回目の検証用データは : 918717737.581258
# 137回目の学習用データは : 1220288185.9962397
# 137回目の検証用データは : 916305760.4450446
# 138回目の学習用データは : 1217426710.864517
# 138回目の検証用データは : 913994893.5516896
# 139回目の学習用データは : 1214679359.116302
# 139回目の検証用データは : 911781001.6675602
# 140回目の学習用データは : 1212041568.9176033
# 140回目の検証用データは : 909660116.6808913
# 141回目の学習用データは : 1209508961.2408698
# 141回目の検証用データは : 907628430.8818187
# 142回目の学習用データは : 1207077332.5186958
# 142回目の検証用データは : 905682290.5122877
# 143回目の学習用データは : 1204742647.593699
# 143回目の検証用データは : 903818189.574984
# 144回目の学習用データは : 1202501032.9525788
# 144回目の検証用データは : 902032763.8908772
# 145回目の学習用データは : 1200348770.232863
# 145回目の検証用データは : 900322785.395384
# 146回目の学習用データは : 1198282289.9913092
# 146回目の検証用データは : 898685156.6635604
# 147回目の学習用データは : 1196298165.723384
# 147回目の検証用データは : 897116905.6551223
# 148回目の学習用データは : 1194393108.123662
# 148回目の検証用データは : 895615180.6704597
# 149回目の学習用データは : 1192563959.5774112
# 149回目の検証用データは : 894177245.5091656
# 150回目の学習用データは : 1190807688.8740113
# 150回目の検証用データは : 892800474.8229489
# 151回目の学習用データは : 1189121386.1332502
# 151回目の検証用データは : 891482349.6551176
# 152回目の学習用データは : 1187502257.9358892
# 152回目の検証用データは : 890220453.1591452
# 153回目の学習用データは : 1185947622.6502464
# 153回目の検証用データは : 889012466.4891186
# 154回目の学習用データは : 1184454905.9468818
# 154回目の検証用データは : 887856164.8551744
# 155回目の学習用データは : 1183021636.4937856
# 155回目の検証用データは : 886749413.7372931
# 156回目の学習用データは : 1181645441.824783
# 156回目の検証用データは : 885690165.2510937
# 157回目の学習用データは : 1180324044.3741589
# 157回目の検証用データは : 884676454.6595268
# 158回目の学習用データは : 1179055257.6707942
# 158回目の検証用データは : 883706397.0246065
# 159回目の学習用データは : 1177836982.68538
# 159回目の検証用データは : 882778183.9935645
# 160回目の学習用データは : 1176667204.3245223
# 160回目の検証用データは : 881890080.7140257
# 161回目の学習用データは : 1175543988.0658216
# 161回目の検証用データは : 881040422.8730271
# 162回目の学習用データは : 1174465476.728233
# 162回目の検証用データは : 880227613.8549159
# 163回目の学習用データは : 1173429887.3722534
# 163回目の検証用データは : 879450122.0133437
# 164回目の学習用データは : 1172435508.3246977
# 164回目の検証用データは : 878706478.0527928
# 165回目の学習用データは : 1171480696.3230453
# 165回目の検証用データは : 877995272.5152277
# 166回目の学習用データは : 1170563873.774528
# 166回目の検証用データは : 877315153.3676583
# 167回目の学習用データは : 1169683526.125343
# 167回目の検証用データは : 876664823.6865671
# 168回目の学習用データは : 1168838199.3355463
# 168回目の検証用データは : 876043039.4353125
# 169回目の学習用データは : 1168026497.45537
# 169回目の検証用データは : 875448607.330777
# 170回目の学習用データは : 1167247080.2988796
# 170回目の検証用データは : 874880382.7956827
# 171回目の学習用データは : 1166498661.2110424
# 171回目の検証用データは : 874337267.9931359
# 172回目の学習用データは : 1165780004.924454
# 172回目の検証用データは : 873818209.9401032
# 173回目の学習用データは : 1165089925.502104
# 173回目の検証用データは : 873322198.6966519
# 174回目の学習用データは : 1164427284.3627222
# 174回目の検証用データは : 872848265.627917
# 175回目の学習用データは : 1163790988.385377
# 175回目の検証用データは : 872395481.735878
# 176回目の学習用データは : 1163179988.0901344
# 176回目の検証用データは : 871962956.0581442
# 177回目の学習用データは : 1162593275.891723
# 177回目の検証用データは : 871549834.1310618
# 178回目の学習用データは : 1162029884.423257
# 178回目の検証用データは : 871155296.514565
# 179回目の学習用データは : 1161488884.9272068
# 179回目の検証用データは : 870778557.3762919
# 180回目の学習用データは : 1160969385.7109082
# 180回目の検証用データは : 870418863.1325904
# 181回目の学習用データは : 1160470530.6640112
# 181回目の検証用データは : 870075491.1441329
# 182回目の学習用データは : 1159991497.8353834
# 182回目の検証用データは : 869747748.4639481
# 183回目の学習用データは : 1159531498.0670705
# 183回目の検証用データは : 869434970.6357719
# 184回目の学習用データは : 1159089773.6830251
# 184回目の検証用データは : 869136520.540693
# 185回目の学習用データは : 1158665597.230397
# 185回目の検証用データは : 868851787.2901654
# 186回目の学習用データは : 1158258270.2712758
# 186回目の検証用データは : 868580185.1635196
# 187回目の学習用データは : 1157867122.222856
# 187回目の検証用データは : 868321152.5881954
# 188回目の学習用データは : 1157491509.2440796
# 188回目の検証用データは : 868074151.1609782
# 189回目の学習用データは : 1157130813.1668856
# 189回目の検証用データは : 867838664.7085985
# 190回目の学習用データは : 1156784440.4702814
# 190回目の検証用データは : 867614198.3861123
# 191回目の学習用データは : 1156451821.295505
# 191回目の検証用データは : 867400277.8115522
# 192回目の学習用データは : 1156132408.5006394
# 192回目の検証用データは : 867196448.235388
# 193回目の学習用データは : 1155825676.7530825
# 193回目の検証用データは : 867002273.7434101
# 194回目の学習用データは : 1155531121.6583657
# 194回目の検証用データは : 866817336.4916866
# 195回目の学習用データは : 1155248258.9238477
# 195回目の検証用データは : 866641235.9723123
# 196回目の学習用データは : 1154976623.5558963
# 196回目の検証用データは : 866473588.3087159
# 197回目の学習用データは : 1154715769.0892031
# 197回目の検証用データは : 866314025.5793369
# 198回目の学習用データは : 1154465266.846951
# 198回目の検証用データは : 866162195.168536
# 199回目の学習用データは : 1154224705.2305853
# 199回目の検証用データは : 866017759.1436471
# 200回目の学習用データは : 1153993689.0380151
# 200回目の検証用データは : 865880393.6571215
# 201回目の学習用データは : 1153771838.809087
# 201回目の検証用データは : 865749788.3727596
# 202回目の学習用データは : 1153558790.1972542
# 202回目の検証用データは : 865625645.9150616
# 203回目の学習用データは : 1153354193.3663762
# 203回目の検証用データは : 865507681.3407716
# 204回目の学習用データは : 1153157712.41165
# 204回目の検証用データは : 865395621.6317242
# 205回目の学習用データは : 1152969024.803701
# 205回目の検証用データは : 865289205.2081406
# 206回目の学習用データは : 1152787820.8549073
# 206回目の検証用データは : 865188181.4615482
# 207回目の学習用データは : 1152613803.207064
# 207回目の検証用データは : 865092310.3065473
# 208回目の学習用データは : 1152446686.339533
# 208回目の検証用データは : 865001361.7506554
# 209回目の学習用データは : 1152286196.0970564
# 209回目の検証用データは : 864915115.4815155
# 210回目の学習用データは : 1152132069.2364476
# 210回目の検証用データは : 864833360.4707623
# 211回目の学習用データは : 1151984052.9914005
# 211回目の検証用データは : 864755894.5938855
# 212回目の学習用データは : 1151841904.6546926
# 212回目の検証用データは : 864682524.2654428
# 213回目の学習用データは : 1151705391.1770875
# 213回目の検証用データは : 864613064.0890089
# 214回目の学習用データは : 1151574288.7822604
# 214回目の検証用データは : 864547336.5212681
# 215回目の学習用データは : 1151448382.5971136
# 215回目の検証用データは : 864485171.5496838
# 216回目の学習用データは : 1151327466.2968602
# 216回目の検証用データは : 864426406.3831991
# 217回目の学習用データは : 1151211341.7642868
# 217回目の検証用データは : 864370885.1554443
# 218回目の学習用データは : 1151099818.7626228
# 218回目の検証用データは : 864318458.6399511
# 219回目の学習用データは : 1150992714.6214845
# 219回目の検証用データは : 864268983.9768907
# 220回目の学習用データは : 1150889853.9353492
# 220回目の検証用データは : 864222324.4108711
# 221回目の学習用データは : 1150791068.2740808
# 221回目の検証用データは : 864178349.0393516
# 222回目の学習用データは : 1150696195.9050076
# 222回目の検証用データは : 864136932.5712475
# 223回目の学習用データは : 1150605081.526097
# 223回目の検証用データは : 864097955.0953151
# 224回目の学習用データは : 1150517576.0097852
# 224回目の検証用データは : 864061301.8579242
# 225回目の学習用データは : 1150433536.1570292
# 225回目の検証用データは : 864026863.0498391
# 226回目の学習用データは : 1150352824.4611762
# 226回目の検証用データは : 863994533.6016517
# 227回目の学習用データは : 1150275308.881258
# 227回目の検証用データは : 863964212.9875098
# 228回目の学習用データは : 1150200862.624333
# 228回目の検証用データは : 863935805.0368162
# 229回目の学習用データは : 1150129363.9365096
# 229回目の検証用データは : 863909217.7535721
# 230回目の学習用データは : 1150060695.9023123
# 230回目の検証用データは : 863884363.1430588
# 231回目の学習用データは : 1149994746.2520497
# 231回目の検証用データは : 863861157.0455648
# 232回目の学習用データは : 1149931407.1768656
# 232回目の検証用データは : 863839518.9768724
# 233回目の学習用データは : 1149870575.1511714
# 233回目の検証用データは : 863819371.9752299
# 234回目の学習用データは : 1149812150.7621562
# 234回目の検証用データは : 863800642.4545544
# 235回目の学習用データは : 1149756038.546099
# 235回目の検証用データは : 863783260.0636106
# 236回目の学習用データは : 1149702146.8312085
# 236回目の検証用データは : 863767157.5509208
# 237回目の学習用データは : 1149650387.5867271
# 237回目の検証用データは : 863752270.6351863
# 238回目の学習用データは : 1149600676.278054
# 238回目の検証用データは : 863738537.8809867
# 239回目の学習用データは : 1149552931.7276418
# 239回目の検証用データは : 863725900.5795517
# 240回目の学習用データは : 1149507075.98144
# 240回目の検証用データは : 863714302.6343973
# 241回目の学習用データは : 1149463034.1806607
# 241回目の検証用データは : 863703690.4516349
# 242回目の学習用データは : 1149420734.438657
# 242回目の検証用データは : 863694012.8347567
# 243回目の学習用データは : 1149380107.7227051
# 243回目の検証用データは : 863685220.8837272
# 244回目の学習用データは : 1149341087.7405019
# 244回目の検証用データは : 863677267.8981986
# 245回目の学習用データは : 1149303610.8311806
# 245回目の検証用データは : 863670109.2846875
# 246回目の学習用データは : 1149267615.8606708
# 246回目の検証用データは : 863663702.4675547
# 247回目の学習用データは : 1149233044.12123
# 247回目の検証用データは : 863658006.8036292
# 248回目の学習用データは : 1149199839.2349703
# 248回目の検証用データは : 863652983.5003356
# 249回目の学習用データは : 1149167947.061236
# 249回目の検証用データは : 863648595.537178
# 250回目の学習用データは : 1149137315.6076648
# 250回目の検証用データは : 863644807.5904495
# 251回目の学習用データは : 1149107894.9447937
# 251回目の検証用データは : 863641585.9610316
# 252回目の学習用データは : 1149079637.124064
# 252回目の検証用データは : 863638898.5051638
# 253回目の学習用データは : 1149052496.0990927
# 253回目の検証用データは : 863636714.5680616
# 254回目の学習用データは : 1149026427.6500783
# 254回目の検証用データは : 863635004.9202654
# 255回目の学習用データは : 1149001389.3112156
# 255回目の検証用データは : 863633741.6966124
# 256回目の学習用データは : 1148977340.3010008
# 256回目の検証用データは : 863632898.3377236
# 257回目の学習用データは : 1148954241.45531
# 257回目の検証用データは : 863632449.533908
# 258回目の学習用データは : 1148932055.1631432
# 258回目の検証用データは : 863632371.1713799
# 259回目の学習用データは : 1148910745.3049235
# 259回目の検証用データは : 863632640.280699
# 260回目の学習用データは : 1148890277.193254
# 260回目の検証用データは : 863633234.9873455
# 261回目の学習用データは : 1148870617.5160306
# 261回目の検証用データは : 863634134.4643378
# 262回目の学習用データは : 1148851734.2818193
# 262回目の検証用データは : 863635318.8868177
# 263回目の学習用データは : 1148833596.7674067
# 263回目の検証用データは : 863636769.3885124
# 264回目の学習用データは : 1148816175.4674363
# 264回目の検証用データは : 863638468.0200095
# 265回目の学習用データは : 1148799442.0460496
# 265回目の検証用データは : 863640397.7087635
# 266回目の学習用データは : 1148783369.2904515
# 266回目の検証用データは : 863642542.2207631
# 267回目の学習用データは : 1148767931.0663192
# 267回目の検証用データは : 863644886.1237968
# 268回目の学習用データは : 1148753102.2749891
# 268回目の検証用データは : 863647414.7522488
# 269回目の学習用データは : 1148738858.8123426
# 269回目の検証用データは : 863650114.1733607
# 270回目の学習用データは : 1148725177.5293312
# 270回目の検証用データは : 863652971.1549056
# 271回目の学習用データは : 1148712036.1940637
# 271回目の検証用データは : 863655973.1342092
# 272回目の学習用データは : 1148699413.455411
# 272回目の検証用データは : 863659108.1884708
# 273回目の学習用データは : 1148687288.808049
# 273回目の検証用データは : 863662365.0063251
# 274回目の学習用データは : 1148675642.558896
# 274回目の検証用データは : 863665732.860597
# 275回目の学習用データは : 1148664455.794884
# 275回目の検証用データは : 863669201.5822014
# 276回目の学習用データは : 1148653710.3520076
# 276回目の検証用データは : 863672761.5351384
# 277回目の学習用データは : 1148643388.7856078
# 277回目の検証用データは : 863676403.5925437
# 278回目の学習用データは : 1148633474.3418345
# 278回目の検証用データは : 863680119.113744
# 279回目の学習用データは : 1148623950.9302402
# 279回目の検証用データは : 863683899.9222853
# 280回目の学習用データは : 1148614803.0974703
# 280回目の検証用データは : 863687738.2848859
# 281回目の学習用データは : 1148606016.0019908
# 281回目の検証用データは : 863691626.8912823
# 282回目の学習用データは : 1148597575.3898234
# 282回目の検証用データは : 863695558.8349266
# 283回目の学習用データは : 1148589467.571247
# 283回目の検証用データは : 863699527.5945055
# 284回目の学習用データは : 1148581679.3984203
# 284回目の検証用データは : 863703527.016243
# 285回目の学習用データは : 1148574198.2438955
# 285回目の検証用データは : 863707551.2969562
# 286回目の学習用データは : 1148567011.9799871
# 286回目の検証用データは : 863711594.9678336
# 287回目の学習用データは : 1148560108.9589558
# 287回目の検証用データは : 863715652.878906
# 288回目の学習用データは : 1148553477.9939837
# 288回目の検証用データは : 863719720.1841812
# 289回目の学習用データは : 1148547108.340902
# 289回目の検証用データは : 863723792.3274143
# 290回目の学習用データは : 1148540989.6806464
# 290回目の検証用データは : 863727865.028491
# 291回目の学習用データは : 1148535112.102407
# 291回目の検証用データは : 863731934.2703928
# 292回目の学習用データは : 1148529466.0874486
# 292回目の検証用データは : 863735996.2867258
# 293回目の学習用データは : 1148524042.4935741
# 293回目の検証用データは : 863740047.5497856
# 294回目の学習用データは : 1148518832.5402021
# 294回目の検証用データは : 863744084.7591401
# 295回目の学習用データは : 1148513827.7940388
# 295回目の検証用データは : 863748104.8307035
# 296回目の学習用データは : 1148509020.155319
# 296回目の検証用データは : 863752104.8862869
# 297回目の学習用データは : 1148504401.8445902
# 297回目の検証用データは : 863756082.2436016
# 298回目の学習用データは : 1148499965.3900254
# 298回目の検証用データは : 863760034.4066981
# 299回目の学習用データは : 1148495703.6152363
# 299回目の検証用データは : 863763959.0568228
# 300回目の学習用データは : 1148491609.6275697
# 300回目の検証用データは : 863767854.0436738

# %%
loss =  slr.loss
val_loss = slr.val_loss

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.title('No_Bias=True', fontsize=15)
plt.xlabel('Iter', fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.plot(range(len(loss)), loss, label='Loss')
plt.plot(range(len(val_loss)), val_loss, label='Val_loss')
plt.legend()


loss =  slr_0.loss
val_loss = slr_0.val_loss

plt.subplot(1, 2, 2)
plt.title('No_Bias=False', fontsize=15)
plt.xlabel('Iter', fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.plot(range(len(loss)), loss, label='Loss')
plt.plot(range(len(val_loss)), val_loss, label='Val_loss')
plt.legend()
plt.show()

# %% [markdown]
# # 【問題7】学習曲線のプロット
# 学習曲線を表示する関数を作成し、実行してください。グラフを見て損失が適切に下がっているかどうか確認してください。
#
# 線形回帰クラスの雛形ではself.loss, self.val_lossに損失を記録しておくようになっているため、入力にはこれを利用してください。
#
# プロット例
# ![image.png](attachment:image.png)

# %% [markdown]
# # 【問題8】（アドバンス課題）バイアス項の除去
# バイアス項
# θ
# 0
#  を抜くと学習がどう変化するか検証してください。また、線形回帰モデルにおけるバイアス項の役割の考察・調査を行ってください。
